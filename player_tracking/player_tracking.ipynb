# %% [markdown]
# Prueba con DeepSORT Realtime

# %%
def getColor(class_name):
    switch = {
        'player': (255, 0, 0),       # Azul
        'basketball': (0, 165, 255), # Naranja
        'rim': (0, 0, 255),          # Rojo
        'made-shot': (0, 255, 0)     # Verde
    }
    return switch.get(class_name, (0, 0, 0)) 

def drawBBox(frame, x1, y1, x2, y2, label, class_name):
    color = getColor(class_name)
    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

def drawPosition(frame, position, position_label):
    cv2.ellipse(frame, (int(position[0]), int(position[1])), (9, 3), 0, 0, 360, (0, 0, 255), -1)
    cv2.putText(frame, position_label, (int(position[0]) - 50, int(position[1]) + 25), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

# %%
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort


object_detector = YOLO("../object_detection/runs/detect/bod_v1/weights/best.pt")

tracker = DeepSort(max_age=50, n_init=5, nms_max_overlap=1.0)

video_path = "../clips/ClipLF1.mp4"
output_path = "../output/ClipLF1_tracking_output.mp4"

cap = cv2.VideoCapture(video_path)
fourcc = cv2.VideoWriter_fourcc(*"avc1")
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

MAX_PLAYERS = 10

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    object_detection_results = object_detector(frame)

    detections = []
    # Análisis de las detecciones de jugadores
    for result in object_detection_results[0].boxes.data.tolist():  # Obtener los resultados como lista
        x1, y1, x2, y2, conf, cls = result  # Coordenadas, confianza y clase
        cls = int(cls)

        # Filtrar solo por las clases deseadas
        if object_detector.names[cls] in ['player'] and conf > 0.5:
            detections.append(([x1, y1, x2-x1, y2-y1], conf, cls))

    tracking_results = tracker.update_tracks(detections, frame=frame)

    # Filtrar solo los tracks confirmados
    confirmed_tracks = [track for track in tracking_results if track.is_confirmed()]

    # Ordenar por track_id (IDs más bajos primero) y mantener solo 10
    if len(confirmed_tracks) > MAX_PLAYERS:
        confirmed_tracks = sorted(confirmed_tracks, key=lambda t: t.track_id)[:MAX_PLAYERS]

    for track in confirmed_tracks:
        track_id = track.track_id  # Obtener el ID del track
        x1, y1, x2, y2 = track.to_ltrb()  # Bounding box en formato [left, top, right, bottom]
        drawBBox(frame, x1, y1, x2, y2, f"ID: {track_id}", 'player')

        position = (int((x1 + x2) / 2), y2)
        position_label = f"x:{int(position[0])} y:{int(position[1])}"
        drawPosition(frame, position, position_label)



    # Mostrar el frame procesado en pantalla
    cv2.imshow('Resultados', frame)

    # Esperar por una tecla: espacio para avanzar, 'q' para salir
    key = cv2.waitKey(0) & 0xFF  # Espera indefinidamente hasta que se presione una tecla
    if key == ord('q'):
        break
    elif key == ord(' '):  # Espacio para continuar
        # Escribir el frame procesado en el video de salida
        out.write(frame)


# Liberar recursos
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Video procesado guardado en {output_path}")
# Out:
# 0: 576x1024 10 players, 1 rim, 29.2ms
# Speed: 4.6ms preprocess, 29.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.9ms
# Speed: 6.2ms preprocess, 23.9ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.8ms
# Speed: 4.7ms preprocess, 24.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.6ms
# Speed: 4.8ms preprocess, 24.6ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.7ms
# Speed: 5.4ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.0ms
# Speed: 5.8ms preprocess, 27.0ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.0ms
# Speed: 5.5ms preprocess, 26.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.0ms
# Speed: 5.4ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.1ms
# Speed: 5.6ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 23.9ms
# Speed: 5.9ms preprocess, 23.9ms inference, 6.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.9ms
# Speed: 6.1ms preprocess, 23.9ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 28.3ms
# Speed: 5.6ms preprocess, 28.3ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.3ms
# Speed: 5.4ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 25.1ms
# Speed: 6.0ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 30.0ms
# Speed: 5.5ms preprocess, 30.0ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.7ms
# Speed: 5.5ms preprocess, 23.7ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.7ms
# Speed: 6.0ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.5ms
# Speed: 5.6ms preprocess, 23.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.7ms
# Speed: 5.5ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 26.3ms
# Speed: 5.5ms preprocess, 26.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.2ms
# Speed: 5.6ms preprocess, 27.2ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.2ms
# Speed: 5.4ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 26.4ms
# Speed: 5.7ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 23.4ms
# Speed: 6.0ms preprocess, 23.4ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 26.2ms
# Speed: 5.3ms preprocess, 26.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.4ms
# Speed: 5.4ms preprocess, 22.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 26.2ms
# Speed: 5.7ms preprocess, 26.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 23.5ms
# Speed: 5.4ms preprocess, 23.5ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.5ms
# Speed: 5.7ms preprocess, 23.5ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 24.7ms
# Speed: 5.6ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 24.4ms
# Speed: 6.4ms preprocess, 24.4ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 22.3ms
# Speed: 5.5ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.5ms
# Speed: 5.5ms preprocess, 22.5ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.7ms
# Speed: 5.5ms preprocess, 22.7ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 26.7ms
# Speed: 5.8ms preprocess, 26.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 27.7ms
# Speed: 5.4ms preprocess, 27.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 25.8ms
# Speed: 7.7ms preprocess, 25.8ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.2ms
# Speed: 6.6ms preprocess, 22.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.2ms
# Speed: 6.1ms preprocess, 22.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.3ms
# Speed: 5.4ms preprocess, 27.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.6ms
# Speed: 5.3ms preprocess, 22.6ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.1ms
# Speed: 6.1ms preprocess, 22.1ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.0ms
# Speed: 6.5ms preprocess, 22.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 22.1ms
# Speed: 5.5ms preprocess, 22.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 22.6ms
# Speed: 5.6ms preprocess, 22.6ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 26.1ms
# Speed: 6.0ms preprocess, 26.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.3ms
# Speed: 5.4ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.1ms
# Speed: 5.5ms preprocess, 22.1ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.4ms
# Speed: 5.3ms preprocess, 22.4ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 27.1ms
# Speed: 5.6ms preprocess, 27.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.8ms
# Speed: 5.6ms preprocess, 26.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.8ms
# Speed: 5.6ms preprocess, 26.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 5.5ms preprocess, 25.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.3ms
# Speed: 5.9ms preprocess, 22.3ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.9ms
# Speed: 5.8ms preprocess, 24.9ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.6ms
# Speed: 5.6ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.7ms
# Speed: 5.5ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 26.6ms
# Speed: 5.6ms preprocess, 26.6ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.7ms
# Speed: 5.6ms preprocess, 25.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 26.8ms
# Speed: 5.6ms preprocess, 26.8ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.2ms
# Speed: 6.1ms preprocess, 24.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.5ms
# Speed: 5.3ms preprocess, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 26.2ms
# Speed: 5.4ms preprocess, 26.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.3ms
# Speed: 5.6ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 12.0ms
# Speed: 4.5ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 13 players, 1 rim, 11.9ms
# Speed: 4.7ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.8ms
# Speed: 5.4ms preprocess, 23.8ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.1ms
# Speed: 4.6ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.1ms
# Speed: 4.6ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 12.4ms
# Speed: 4.4ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 12.4ms
# Speed: 4.6ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 23.6ms
# Speed: 4.9ms preprocess, 23.6ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 25.3ms
# Speed: 5.8ms preprocess, 25.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 24.2ms
# Speed: 6.3ms preprocess, 24.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 23.4ms
# Speed: 6.0ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 26.2ms
# Speed: 5.2ms preprocess, 26.2ms inference, 2.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 24.4ms
# Speed: 6.5ms preprocess, 24.4ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 23.4ms
# Speed: 5.6ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 23.0ms
# Speed: 5.9ms preprocess, 23.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.9ms
# Speed: 5.4ms preprocess, 22.9ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 27.0ms
# Speed: 5.7ms preprocess, 27.0ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.7ms
# Speed: 6.8ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.6ms
# Speed: 6.3ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.5ms
# Speed: 5.6ms preprocess, 22.5ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.3ms
# Speed: 5.6ms preprocess, 26.3ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 27.4ms
# Speed: 5.5ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 22.6ms
# Speed: 5.4ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 27.6ms
# Speed: 5.5ms preprocess, 27.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.6ms
# Speed: 5.8ms preprocess, 22.6ms inference, 5.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.8ms
# Speed: 5.6ms preprocess, 22.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.5ms
# Speed: 5.4ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.7ms
# Speed: 5.4ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.6ms
# Speed: 5.6ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.5ms
# Speed: 7.7ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 28.0ms
# Speed: 5.3ms preprocess, 28.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.3ms
# Speed: 6.5ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.3ms
# Speed: 5.6ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 25.9ms
# Speed: 5.8ms preprocess, 25.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 22.7ms
# Speed: 5.7ms preprocess, 22.7ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.8ms
# Speed: 5.9ms preprocess, 27.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.6ms
# Speed: 6.1ms preprocess, 22.6ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.9ms
# Speed: 6.7ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.2ms
# Speed: 5.6ms preprocess, 22.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.9ms
# Speed: 5.7ms preprocess, 21.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.8ms
# Speed: 5.9ms preprocess, 24.8ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.2ms
# Speed: 6.1ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.9ms
# Speed: 5.7ms preprocess, 23.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.1ms
# Speed: 5.8ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 21.8ms
# Speed: 5.6ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.0ms
# Speed: 5.6ms preprocess, 22.0ms inference, 4.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.4ms
# Speed: 5.8ms preprocess, 25.4ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 21.5ms
# Speed: 5.4ms preprocess, 21.5ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 21.7ms
# Speed: 7.2ms preprocess, 21.7ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.9ms
# Speed: 5.6ms preprocess, 21.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 24.9ms
# Speed: 6.0ms preprocess, 24.9ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.3ms
# Speed: 5.6ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.0ms
# Speed: 5.8ms preprocess, 24.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.2ms
# Speed: 5.8ms preprocess, 23.2ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.9ms
# Speed: 5.6ms preprocess, 21.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 25.3ms
# Speed: 5.6ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 5.5ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.5ms
# Speed: 5.3ms preprocess, 26.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.9ms
# Speed: 5.7ms preprocess, 21.9ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 23.8ms
# Speed: 5.9ms preprocess, 23.8ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.6ms
# Speed: 5.6ms preprocess, 21.6ms inference, 5.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 17.5ms
# Speed: 6.9ms preprocess, 17.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.3ms
# Speed: 5.4ms preprocess, 24.3ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 12.2ms
# Speed: 4.4ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 12.2ms
# Speed: 4.3ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.5ms
# Speed: 4.7ms preprocess, 24.5ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 12.3ms
# Speed: 4.5ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 11.9ms
# Speed: 4.5ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.3ms
# Speed: 5.2ms preprocess, 21.3ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 12.7ms
# Speed: 5.1ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.4ms
# Speed: 5.4ms preprocess, 21.4ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 27.7ms
# Speed: 5.9ms preprocess, 27.7ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.0ms
# Speed: 5.7ms preprocess, 26.0ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 27.8ms
# Speed: 5.9ms preprocess, 27.8ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.9ms
# Speed: 6.6ms preprocess, 23.9ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.3ms
# Speed: 5.6ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 7.1ms preprocess, 25.5ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.4ms
# Speed: 5.4ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 5.4ms preprocess, 25.5ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 27.5ms
# Speed: 5.6ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 23.2ms
# Speed: 5.5ms preprocess, 23.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.3ms
# Speed: 5.7ms preprocess, 23.3ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.6ms
# Speed: 5.4ms preprocess, 28.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.9ms
# Speed: 5.5ms preprocess, 22.9ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.6ms
# Speed: 5.5ms preprocess, 26.6ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.9ms
# Speed: 5.6ms preprocess, 22.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 24.2ms
# Speed: 5.5ms preprocess, 24.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 22.8ms
# Speed: 5.5ms preprocess, 22.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 24.0ms
# Speed: 5.6ms preprocess, 24.0ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 28.2ms
# Speed: 5.3ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.0ms
# Speed: 7.9ms preprocess, 23.0ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 22.5ms
# Speed: 6.1ms preprocess, 22.5ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.4ms
# Speed: 5.4ms preprocess, 28.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 22.0ms
# Speed: 6.9ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 24.8ms
# Speed: 5.6ms preprocess, 24.8ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.6ms
# Speed: 5.6ms preprocess, 24.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.9ms
# Speed: 7.7ms preprocess, 21.9ms inference, 5.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 24.7ms
# Speed: 6.4ms preprocess, 24.7ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 22.0ms
# Speed: 5.6ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 2 rims, 25.1ms
# Speed: 5.3ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 2 rims, 21.8ms
# Speed: 5.6ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 24.1ms
# Speed: 5.8ms preprocess, 24.1ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.4ms
# Speed: 5.6ms preprocess, 25.4ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.6ms
# Speed: 6.2ms preprocess, 26.6ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 25.7ms
# Speed: 5.4ms preprocess, 25.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.1ms
# Speed: 6.1ms preprocess, 24.1ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.5ms
# Speed: 6.2ms preprocess, 24.5ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.3ms
# Speed: 5.4ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.0ms
# Speed: 6.0ms preprocess, 22.0ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.8ms
# Speed: 5.4ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.0ms
# Speed: 5.5ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.1ms
# Speed: 5.7ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.0ms
# Speed: 5.6ms preprocess, 26.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 26.0ms
# Speed: 5.5ms preprocess, 26.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.9ms
# Speed: 6.0ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 5 players, 2 rims, 23.8ms
# Speed: 5.3ms preprocess, 23.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 made-shot, 6 players, 2 rims, 21.8ms
# Speed: 5.5ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 5 players, 2 rims, 21.7ms
# Speed: 7.2ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 made-shot, 8 players, 2 rims, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 8 players, 2 rims, 25.3ms
# Speed: 5.4ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 made-shot, 6 players, 2 rims, 22.1ms
# Speed: 5.9ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 5 players, 1 rim, 25.3ms
# Speed: 5.7ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 6 players, 1 rim, 25.7ms
# Speed: 7.4ms preprocess, 25.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 1 made-shot, 9 players, 1 rim, 22.2ms
# Speed: 5.4ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 9 players, 1 rim, 27.4ms
# Speed: 5.4ms preprocess, 27.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 1 made-shot, 6 players, 1 rim, 23.4ms
# Speed: 5.5ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 1 made-shot, 9 players, 2 rims, 27.9ms
# Speed: 5.6ms preprocess, 27.9ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.8ms
# Speed: 5.4ms preprocess, 24.8ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 22.3ms
# Speed: 5.6ms preprocess, 22.3ms inference, 5.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.8ms
# Speed: 7.1ms preprocess, 26.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.2ms
# Speed: 5.9ms preprocess, 22.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 21.7ms
# Speed: 5.4ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.8ms
# Speed: 6.5ms preprocess, 21.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 26.4ms
# Speed: 5.4ms preprocess, 26.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.6ms
# Speed: 5.5ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.4ms
# Speed: 6.7ms preprocess, 24.4ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.5ms
# Speed: 7.9ms preprocess, 25.5ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.2ms
# Speed: 6.0ms preprocess, 21.2ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.7ms
# Speed: 5.5ms preprocess, 23.7ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.6ms
# Speed: 5.5ms preprocess, 25.6ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.2ms
# Speed: 5.6ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.0ms
# Speed: 6.1ms preprocess, 24.0ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.7ms
# Speed: 6.2ms preprocess, 23.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.5ms
# Speed: 5.3ms preprocess, 24.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 23.7ms
# Speed: 5.6ms preprocess, 23.7ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.5ms
# Speed: 5.5ms preprocess, 23.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 26.9ms
# Speed: 5.7ms preprocess, 26.9ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 23.0ms
# Speed: 5.4ms preprocess, 23.0ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.6ms
# Speed: 7.7ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.0ms
# Speed: 5.3ms preprocess, 28.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.2ms
# Speed: 5.2ms preprocess, 24.2ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.5ms
# Speed: 4.6ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.9ms
# Speed: 5.6ms preprocess, 24.9ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.7ms
# Speed: 4.5ms preprocess, 23.7ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 12.0ms
# Speed: 4.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.2ms
# Speed: 4.5ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 11.8ms
# Speed: 4.6ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.6ms
# Speed: 6.2ms preprocess, 25.6ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.9ms
# Speed: 5.9ms preprocess, 25.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.2ms
# Speed: 7.5ms preprocess, 28.2ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.5ms
# Speed: 5.4ms preprocess, 26.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.7ms
# Speed: 5.7ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.0ms
# Speed: 5.5ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 22.2ms
# Speed: 5.7ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 12 players, 1 rim, 25.9ms
# Speed: 6.4ms preprocess, 25.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 26.4ms
# Speed: 8.6ms preprocess, 26.4ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.0ms
# Speed: 5.6ms preprocess, 24.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.8ms
# Speed: 5.9ms preprocess, 21.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.6ms
# Speed: 5.3ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.2ms
# Speed: 5.3ms preprocess, 26.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.6ms
# Speed: 5.3ms preprocess, 21.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.6ms
# Speed: 5.4ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.6ms
# Speed: 5.5ms preprocess, 21.6ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 22.7ms
# Speed: 5.4ms preprocess, 22.7ms inference, 3.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.3ms
# Speed: 5.3ms preprocess, 26.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.4ms
# Speed: 5.4ms preprocess, 25.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.5ms
# Speed: 5.4ms preprocess, 26.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.5ms
# Speed: 5.3ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.1ms
# Speed: 4.6ms preprocess, 24.1ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 13.3ms
# Speed: 4.4ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 25.7ms
# Speed: 5.1ms preprocess, 25.7ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.3ms
# Speed: 4.7ms preprocess, 24.3ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.9ms
# Speed: 4.7ms preprocess, 23.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.6ms
# Speed: 5.2ms preprocess, 24.6ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
# Video procesado guardado en ../output/ClipLF1_tracking_output.mp4

# %% [markdown]
# Tracking V2

# %%
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort


object_detector = YOLO("../object_detection/runs/detect/bod_v1/weights/best.pt")

tracker = DeepSort(max_age=50, n_init=5, nms_max_overlap=1.0)

video_path = "../clips/ClipLF1.mp4"
output_path = "../output/ClipLF1_tracking_output.mp4"

cap = cv2.VideoCapture(video_path)
fourcc = cv2.VideoWriter_fourcc(*"avc1")
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

MAX_PLAYERS = 10
# Diccionario para mapear track_id originales a IDs fijos (1-10)
id_mapping = {}
lost_ids = set(range(1, MAX_PLAYERS + 1))  # IDs disponibles (1-10)
active_ids = set()  # IDs actualmente asignados

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    object_detection_results = object_detector(frame)

    detections = []
    # Análisis de las detecciones de jugadores
    for result in object_detection_results[0].boxes.data.tolist():  # Obtener los resultados como lista
        x1, y1, x2, y2, conf, cls = result  # Coordenadas, confianza y clase
        cls = int(cls)

        # Filtrar solo por las clases deseadas
        if object_detector.names[cls] in ['player'] and conf > 0.5:
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls))

    tracking_results = tracker.update_tracks(detections, frame=frame)

    # Filtrar solo los tracks confirmados
    confirmed_tracks = [track for track in tracking_results if track.is_confirmed()]

    for track in confirmed_tracks:
        original_id = track.track_id  # ID asignado por DeepSORT

        if original_id in id_mapping:
            fixed_id = id_mapping[original_id]  # Usar el ID ya asignado
        elif lost_ids:
            fixed_id = lost_ids.pop()  # Tomar un ID libre
            id_mapping[original_id] = fixed_id  # Asignarlo al nuevo jugador
            active_ids.add(fixed_id)  # Registrar el ID como activo
        else:
            continue  # Si no hay IDs disponibles, ignoramos la detección

        x1, y1, x2, y2 = track.to_ltrb()  # Bounding box en formato [left, top, right, bottom]
        drawBBox(frame, x1, y1, x2, y2, f"ID: {fixed_id}", 'player')

        position = (int((x1 + x2) / 2), y2)
        position_label = f"x:{int(position[0])} y:{int(position[1])}"
        drawPosition(frame, position, position_label)

    # Identificar jugadores que han desaparecido
    active_now = {id_mapping[track.track_id] for track in confirmed_tracks if track.track_id in id_mapping}
    lost_ids.update(active_ids - active_now)  # Recuperar IDs de jugadores perdidos
    active_ids = active_now  # Actualizar IDs activos

    # Mostrar el frame procesado en pantalla
    cv2.imshow('Resultados', frame)

    # Esperar por una tecla: espacio para avanzar, 'q' para salir
    key = cv2.waitKey(0) & 0xFF  # Espera indefinidamente hasta que se presione una tecla
    if key == ord('q'):
        break
    elif key == ord(' '):  # Espacio para continuar
        # Escribir el frame procesado en el video de salida
        out.write(frame)


# Liberar recursos
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Video procesado guardado en {output_path}")
# Out:
# 0: 576x1024 10 players, 1 rim, 29.2ms
# Speed: 4.6ms preprocess, 29.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.9ms
# Speed: 6.2ms preprocess, 23.9ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.8ms
# Speed: 4.7ms preprocess, 24.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.6ms
# Speed: 4.8ms preprocess, 24.6ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.7ms
# Speed: 5.4ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.0ms
# Speed: 5.8ms preprocess, 27.0ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.0ms
# Speed: 5.5ms preprocess, 26.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.0ms
# Speed: 5.4ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.1ms
# Speed: 5.6ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 23.9ms
# Speed: 5.9ms preprocess, 23.9ms inference, 6.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.9ms
# Speed: 6.1ms preprocess, 23.9ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 28.3ms
# Speed: 5.6ms preprocess, 28.3ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.3ms
# Speed: 5.4ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 25.1ms
# Speed: 6.0ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 30.0ms
# Speed: 5.5ms preprocess, 30.0ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.7ms
# Speed: 5.5ms preprocess, 23.7ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.7ms
# Speed: 6.0ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.5ms
# Speed: 5.6ms preprocess, 23.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.7ms
# Speed: 5.5ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 26.3ms
# Speed: 5.5ms preprocess, 26.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.2ms
# Speed: 5.6ms preprocess, 27.2ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.2ms
# Speed: 5.4ms preprocess, 25.2ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 26.4ms
# Speed: 5.7ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 23.4ms
# Speed: 6.0ms preprocess, 23.4ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 26.2ms
# Speed: 5.3ms preprocess, 26.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.4ms
# Speed: 5.4ms preprocess, 22.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 26.2ms
# Speed: 5.7ms preprocess, 26.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 23.5ms
# Speed: 5.4ms preprocess, 23.5ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 23.5ms
# Speed: 5.7ms preprocess, 23.5ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 24.7ms
# Speed: 5.6ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 24.4ms
# Speed: 6.4ms preprocess, 24.4ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 22.3ms
# Speed: 5.5ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.5ms
# Speed: 5.5ms preprocess, 22.5ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.7ms
# Speed: 5.5ms preprocess, 22.7ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 26.7ms
# Speed: 5.8ms preprocess, 26.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 27.7ms
# Speed: 5.4ms preprocess, 27.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 25.8ms
# Speed: 7.7ms preprocess, 25.8ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.2ms
# Speed: 6.6ms preprocess, 22.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 22.2ms
# Speed: 6.1ms preprocess, 22.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.3ms
# Speed: 5.4ms preprocess, 27.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.6ms
# Speed: 5.3ms preprocess, 22.6ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.1ms
# Speed: 6.1ms preprocess, 22.1ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.0ms
# Speed: 6.5ms preprocess, 22.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 22.1ms
# Speed: 5.5ms preprocess, 22.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 22.6ms
# Speed: 5.6ms preprocess, 22.6ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 26.1ms
# Speed: 6.0ms preprocess, 26.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.3ms
# Speed: 5.4ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.1ms
# Speed: 5.5ms preprocess, 22.1ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.4ms
# Speed: 5.3ms preprocess, 22.4ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 27.1ms
# Speed: 5.6ms preprocess, 27.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.8ms
# Speed: 5.6ms preprocess, 26.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.8ms
# Speed: 5.6ms preprocess, 26.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 5.5ms preprocess, 25.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.3ms
# Speed: 5.9ms preprocess, 22.3ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.9ms
# Speed: 5.8ms preprocess, 24.9ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.6ms
# Speed: 5.6ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.7ms
# Speed: 5.5ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 26.6ms
# Speed: 5.6ms preprocess, 26.6ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.7ms
# Speed: 5.6ms preprocess, 25.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 26.8ms
# Speed: 5.6ms preprocess, 26.8ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.2ms
# Speed: 6.1ms preprocess, 24.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.5ms
# Speed: 5.3ms preprocess, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 26.2ms
# Speed: 5.4ms preprocess, 26.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.3ms
# Speed: 5.6ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 12.0ms
# Speed: 4.5ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 13 players, 1 rim, 11.9ms
# Speed: 4.7ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.8ms
# Speed: 5.4ms preprocess, 23.8ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.1ms
# Speed: 4.6ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.1ms
# Speed: 4.6ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 12.4ms
# Speed: 4.4ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 12.4ms
# Speed: 4.6ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 23.6ms
# Speed: 4.9ms preprocess, 23.6ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 25.3ms
# Speed: 5.8ms preprocess, 25.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 24.2ms
# Speed: 6.3ms preprocess, 24.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 23.4ms
# Speed: 6.0ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 26.2ms
# Speed: 5.2ms preprocess, 26.2ms inference, 2.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 24.4ms
# Speed: 6.5ms preprocess, 24.4ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 23.4ms
# Speed: 5.6ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 23.0ms
# Speed: 5.9ms preprocess, 23.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.9ms
# Speed: 5.4ms preprocess, 22.9ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 27.0ms
# Speed: 5.7ms preprocess, 27.0ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.7ms
# Speed: 6.8ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.6ms
# Speed: 6.3ms preprocess, 25.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.5ms
# Speed: 5.6ms preprocess, 22.5ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.3ms
# Speed: 5.6ms preprocess, 26.3ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 27.4ms
# Speed: 5.5ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 22.6ms
# Speed: 5.4ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 27.6ms
# Speed: 5.5ms preprocess, 27.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.6ms
# Speed: 5.8ms preprocess, 22.6ms inference, 5.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.8ms
# Speed: 5.6ms preprocess, 22.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.5ms
# Speed: 5.4ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.7ms
# Speed: 5.4ms preprocess, 22.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.6ms
# Speed: 5.6ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.5ms
# Speed: 7.7ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 28.0ms
# Speed: 5.3ms preprocess, 28.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.3ms
# Speed: 6.5ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.3ms
# Speed: 5.6ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 25.9ms
# Speed: 5.8ms preprocess, 25.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 22.7ms
# Speed: 5.7ms preprocess, 22.7ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 27.8ms
# Speed: 5.9ms preprocess, 27.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.6ms
# Speed: 6.1ms preprocess, 22.6ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.9ms
# Speed: 6.7ms preprocess, 21.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.2ms
# Speed: 5.6ms preprocess, 22.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.9ms
# Speed: 5.7ms preprocess, 21.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.8ms
# Speed: 5.9ms preprocess, 24.8ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.2ms
# Speed: 6.1ms preprocess, 25.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.9ms
# Speed: 5.7ms preprocess, 23.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.1ms
# Speed: 5.8ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 21.8ms
# Speed: 5.6ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.0ms
# Speed: 5.6ms preprocess, 22.0ms inference, 4.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.4ms
# Speed: 5.8ms preprocess, 25.4ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 21.5ms
# Speed: 5.4ms preprocess, 21.5ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 21.7ms
# Speed: 7.2ms preprocess, 21.7ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.9ms
# Speed: 5.6ms preprocess, 21.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 24.9ms
# Speed: 6.0ms preprocess, 24.9ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.3ms
# Speed: 5.6ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.0ms
# Speed: 5.8ms preprocess, 24.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.2ms
# Speed: 5.8ms preprocess, 23.2ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.9ms
# Speed: 5.6ms preprocess, 21.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 25.3ms
# Speed: 5.6ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 5.5ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.5ms
# Speed: 5.3ms preprocess, 26.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.9ms
# Speed: 5.7ms preprocess, 21.9ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 23.8ms
# Speed: 5.9ms preprocess, 23.8ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.6ms
# Speed: 5.6ms preprocess, 21.6ms inference, 5.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 17.5ms
# Speed: 6.9ms preprocess, 17.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.3ms
# Speed: 5.4ms preprocess, 24.3ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 12.2ms
# Speed: 4.4ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 12.2ms
# Speed: 4.3ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.5ms
# Speed: 4.7ms preprocess, 24.5ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 12.3ms
# Speed: 4.5ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 11.9ms
# Speed: 4.5ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.3ms
# Speed: 5.2ms preprocess, 21.3ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 12.7ms
# Speed: 5.1ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.4ms
# Speed: 5.4ms preprocess, 21.4ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 27.7ms
# Speed: 5.9ms preprocess, 27.7ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.0ms
# Speed: 5.7ms preprocess, 26.0ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 27.8ms
# Speed: 5.9ms preprocess, 27.8ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.9ms
# Speed: 6.6ms preprocess, 23.9ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.3ms
# Speed: 5.6ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 7.1ms preprocess, 25.5ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 24.4ms
# Speed: 5.4ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.5ms
# Speed: 5.4ms preprocess, 25.5ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 27.5ms
# Speed: 5.6ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 23.2ms
# Speed: 5.5ms preprocess, 23.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.3ms
# Speed: 5.7ms preprocess, 23.3ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.6ms
# Speed: 5.4ms preprocess, 28.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.9ms
# Speed: 5.5ms preprocess, 22.9ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.6ms
# Speed: 5.5ms preprocess, 26.6ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.9ms
# Speed: 5.6ms preprocess, 22.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 24.2ms
# Speed: 5.5ms preprocess, 24.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 22.8ms
# Speed: 5.5ms preprocess, 22.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 24.0ms
# Speed: 5.6ms preprocess, 24.0ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 28.2ms
# Speed: 5.3ms preprocess, 28.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.0ms
# Speed: 7.9ms preprocess, 23.0ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 22.5ms
# Speed: 6.1ms preprocess, 22.5ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.4ms
# Speed: 5.4ms preprocess, 28.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 22.0ms
# Speed: 6.9ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 24.8ms
# Speed: 5.6ms preprocess, 24.8ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.6ms
# Speed: 5.6ms preprocess, 24.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 21.9ms
# Speed: 7.7ms preprocess, 21.9ms inference, 5.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 24.7ms
# Speed: 6.4ms preprocess, 24.7ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 22.0ms
# Speed: 5.6ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 2 rims, 25.1ms
# Speed: 5.3ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 2 rims, 21.8ms
# Speed: 5.6ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 24.1ms
# Speed: 5.8ms preprocess, 24.1ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 25.4ms
# Speed: 5.6ms preprocess, 25.4ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.6ms
# Speed: 6.2ms preprocess, 26.6ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 25.7ms
# Speed: 5.4ms preprocess, 25.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.1ms
# Speed: 6.1ms preprocess, 24.1ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.5ms
# Speed: 6.2ms preprocess, 24.5ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 27.2ms
# Speed: 5.5ms preprocess, 27.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.3ms
# Speed: 5.4ms preprocess, 22.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.0ms
# Speed: 6.0ms preprocess, 22.0ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.8ms
# Speed: 5.4ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.0ms
# Speed: 5.5ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.1ms
# Speed: 5.7ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 26.0ms
# Speed: 5.6ms preprocess, 26.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 26.0ms
# Speed: 5.5ms preprocess, 26.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.9ms
# Speed: 6.0ms preprocess, 25.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 5 players, 2 rims, 23.8ms
# Speed: 5.3ms preprocess, 23.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 made-shot, 6 players, 2 rims, 21.8ms
# Speed: 5.5ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 5 players, 2 rims, 21.7ms
# Speed: 7.2ms preprocess, 21.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 made-shot, 8 players, 2 rims, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 8 players, 2 rims, 25.3ms
# Speed: 5.4ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 made-shot, 6 players, 2 rims, 22.1ms
# Speed: 5.9ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 5 players, 1 rim, 25.3ms
# Speed: 5.7ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 6 players, 1 rim, 25.7ms
# Speed: 7.4ms preprocess, 25.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 1 made-shot, 9 players, 1 rim, 22.2ms
# Speed: 5.4ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 1 made-shot, 9 players, 1 rim, 27.4ms
# Speed: 5.4ms preprocess, 27.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 1 made-shot, 6 players, 1 rim, 23.4ms
# Speed: 5.5ms preprocess, 23.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 1 made-shot, 9 players, 2 rims, 27.9ms
# Speed: 5.6ms preprocess, 27.9ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.8ms
# Speed: 5.4ms preprocess, 24.8ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 22.3ms
# Speed: 5.6ms preprocess, 22.3ms inference, 5.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 26.8ms
# Speed: 7.1ms preprocess, 26.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 22.2ms
# Speed: 5.9ms preprocess, 22.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 21.7ms
# Speed: 5.4ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.8ms
# Speed: 6.5ms preprocess, 21.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 26.4ms
# Speed: 5.4ms preprocess, 26.4ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.6ms
# Speed: 5.5ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 24.4ms
# Speed: 6.7ms preprocess, 24.4ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 25.5ms
# Speed: 7.9ms preprocess, 25.5ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 21.2ms
# Speed: 6.0ms preprocess, 21.2ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.7ms
# Speed: 5.5ms preprocess, 23.7ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.6ms
# Speed: 5.5ms preprocess, 25.6ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.2ms
# Speed: 5.6ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.0ms
# Speed: 6.1ms preprocess, 24.0ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 23.7ms
# Speed: 6.2ms preprocess, 23.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 24.5ms
# Speed: 5.3ms preprocess, 24.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 23.7ms
# Speed: 5.6ms preprocess, 23.7ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 23.5ms
# Speed: 5.5ms preprocess, 23.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 26.9ms
# Speed: 5.7ms preprocess, 26.9ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 23.0ms
# Speed: 5.4ms preprocess, 23.0ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.6ms
# Speed: 7.7ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.0ms
# Speed: 5.3ms preprocess, 28.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.2ms
# Speed: 5.2ms preprocess, 24.2ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.5ms
# Speed: 4.6ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.9ms
# Speed: 5.6ms preprocess, 24.9ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.7ms
# Speed: 4.5ms preprocess, 23.7ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 12.0ms
# Speed: 4.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 12.2ms
# Speed: 4.5ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 11.8ms
# Speed: 4.6ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.6ms
# Speed: 6.2ms preprocess, 25.6ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 25.9ms
# Speed: 5.9ms preprocess, 25.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 28.2ms
# Speed: 7.5ms preprocess, 28.2ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.5ms
# Speed: 5.4ms preprocess, 26.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 22.7ms
# Speed: 5.7ms preprocess, 22.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 22.0ms
# Speed: 5.5ms preprocess, 22.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 22.2ms
# Speed: 5.7ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 12 players, 1 rim, 25.9ms
# Speed: 6.4ms preprocess, 25.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 26.4ms
# Speed: 8.6ms preprocess, 26.4ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.0ms
# Speed: 5.6ms preprocess, 24.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.8ms
# Speed: 5.9ms preprocess, 21.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.6ms
# Speed: 5.3ms preprocess, 21.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.2ms
# Speed: 5.3ms preprocess, 26.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 21.6ms
# Speed: 5.3ms preprocess, 21.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 21.6ms
# Speed: 5.4ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.6ms
# Speed: 5.5ms preprocess, 21.6ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 22.7ms
# Speed: 5.4ms preprocess, 22.7ms inference, 3.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.3ms
# Speed: 5.3ms preprocess, 26.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 25.4ms
# Speed: 5.4ms preprocess, 25.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 26.5ms
# Speed: 5.4ms preprocess, 26.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 21.5ms
# Speed: 5.3ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.1ms
# Speed: 4.6ms preprocess, 24.1ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 13.3ms
# Speed: 4.4ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 25.7ms
# Speed: 5.1ms preprocess, 25.7ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 24.3ms
# Speed: 4.7ms preprocess, 24.3ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 23.9ms
# Speed: 4.7ms preprocess, 23.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 24.6ms
# Speed: 5.2ms preprocess, 24.6ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
# Video procesado guardado en ../output/ClipLF1_tracking_output.mp4
