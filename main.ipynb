# %% [markdown]
# Match Selection

# %%
import os

# Directorio raíz donde se guardan los resultados
INPUT_DIR = "input"
OUTPUT_DIR = "output"

# Buscar carpetas disponibles
partidos_disponibles = [
    p for p in os.listdir(INPUT_DIR)
    if os.path.isdir(os.path.join(INPUT_DIR, p))
]

# Mostrar opciones
print("📁 Partidos disponibles:")
for i, partido in enumerate(partidos_disponibles):
    print(f"  [{i}] {partido}")

# Pedir selección
indice = input("\n🟢 Ingrese el número del partido que desea analizar: ")

try:
    indice = int(indice)
    partido_seleccionado = partidos_disponibles[indice]
    partido_input_path = os.path.join(INPUT_DIR, partido_seleccionado)
    partido_output_path = os.path.join(OUTPUT_DIR, partido_seleccionado)
    print(f"\n✅ Partido seleccionado: {partido_seleccionado}")
except (ValueError, IndexError):
    raise ValueError("❌ Selección inválida. Por favor reinicie y elija un número válido.")
# Out:
# 📁 Partidos disponibles:
#   [0] example
#   [1] partido1
#
# ✅ Partido seleccionado: partido1

# %% [markdown]
# Homography Estimation

# %%
import os
import numpy as np
import cv2
from skimage import transform

# --- CONFIGURACIÓN ---
INPUT_DIR = "input"
OUTPUT_DIR = "output"
DIAGRAM_POINTS = [(170, 50), (288, 50), (288, 188), (170, 188)]

# --- FUNCIONES AUXILIARES ---

def get_user_points(image, window_name="Selecciona 4 puntos"):
    points = []
    def click_event(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN and len(points) < 4:
            points.append((x, y))
            img_copy = image.copy()
            for pt in points:
                cv2.circle(img_copy, pt, 5, (0, 255, 0), -1)
            cv2.imshow(window_name, img_copy)
            if len(points) == 4:
                cv2.destroyAllWindows()
    cv2.imshow(window_name, image)
    cv2.setMouseCallback(window_name, click_event)
    cv2.waitKey(0)
    return points

def ordenar_puntos(puntos):
    puntos = np.array(puntos)
    idx_visual_ymin = np.argmax(puntos[:, 1])  # Más abajo
    idx_visual_ymax = np.argmin(puntos[:, 1])  # Más arriba
    lado_derecho = puntos[idx_visual_ymax][0] > puntos[idx_visual_ymin][0]

    idx_xmin = np.argmin(puntos[:, 0])
    idx_xmax = np.argmax(puntos[:, 0])
    idx_ymin = np.argmin(puntos[:, 1])
    idx_ymax = np.argmax(puntos[:, 1])

    if lado_derecho:
        inf_izq = puntos[idx_xmin]
        sup_der = puntos[idx_xmax]
        inf_der = puntos[idx_ymax]
        sup_izq = puntos[idx_ymin]
    else:
        inf_der = puntos[idx_xmax]
        sup_izq = puntos[idx_xmin]
        inf_izq = puntos[idx_ymax]
        sup_der = puntos[idx_ymin]

    return np.array([sup_izq, sup_der, inf_der, inf_izq])

def ensure_output_dirs(base_path):
    for subfolder in ['homography_matrices', 'clips', 'csv', 'analysis']:
        os.makedirs(os.path.join(base_path, subfolder), exist_ok=True)

# --- FLUJO PRINCIPAL ---

print(f"\nProcesando partido: {partido}")
partido_output_path = os.path.join(OUTPUT_DIR, partido)
ensure_output_dirs(partido_output_path)

for clip_name in os.listdir(partido_input_path):
    if not clip_name.endswith(".mp4"):
        continue

    clip_path = os.path.join(partido_input_path, clip_name)
    cap = cv2.VideoCapture(clip_path)
    ret, frame = cap.read()
    cap.release()

    if not ret:
        print(f"❌ No se pudo leer: {clip_name}")
        continue

    print(f"\n🎥 Clip: {clip_name}")
    puntos = get_user_points(frame.copy(), f"Selecciona 4 puntos para {clip_name}")
    puntos_ordenados = ordenar_puntos(puntos)

    tform = transform.estimate_transform(
        'projective',
        np.array(puntos_ordenados, dtype=np.float32),
        np.array(DIAGRAM_POINTS, dtype=np.float32)
    )

    homography_matrix = tform.params
    clip_base = os.path.splitext(clip_name)[0]
    matrix_path = os.path.join(partido_output_path, 'homography_matrices', f"{clip_base}.npy")
    np.save(matrix_path, homography_matrix)
    print(f"✅ Homografía guardada en: {matrix_path}")
# Out:
# Procesando partido: partido1
#
# 🎥 Clip: ClipLF1.mp4
# ✅ Homografía guardada en: output\partido1\homography_matrices\ClipLF1.npy
#
# 🎥 Clip: ClipLF2.mp4
# ✅ Homografía guardada en: output\partido1\homography_matrices\ClipLF2.npy
#
# 🎥 Clip: ClipS1.mp4
# ✅ Homografía guardada en: output\partido1\homography_matrices\ClipS1.npy
#
# 🎥 Clip: ClipS2.mp4
# ✅ Homografía guardada en: output\partido1\homography_matrices\ClipS2.npy

# %% [markdown]
# Player tracking and shooting detection

# %%
from ultralytics import YOLO

# --- Cargar modelos YOLO una vez ---
shoot_detector = YOLO("modules/action_recognition/runs/detect/bsr_v2/weights/best.pt")
object_detector = YOLO("modules/object_detection/runs/detect/bod_v1/weights/best.pt")

def getColor(class_name):
    switch = {
        'player': (255, 0, 0),       # Azul
        'basketball': (0, 165, 255), # Naranja
        'rim': (0, 0, 255),          # Rojo
        'made-shot': (0, 255, 0)     # Verde
    }
    return switch.get(class_name, (0, 0, 0)) 

def drawBBox(frame, x1, y1, x2, y2, label, class_name):
    color = getColor(class_name)
    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

def drawPosition(frame, position, position_label):
    cv2.ellipse(frame, (int(position[0]), int(position[1])), (9, 3), 0, 0, 360, (0, 0, 255), -1)
    cv2.putText(frame, position_label, (int(position[0]) - 50, int(position[1]) + 25), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

def transform_point(position, tform):
    point = np.array([position], dtype=np.float32)
    return tform(point)[0]


# Procesar cada clip de video
for clip_name in os.listdir(partido_input_path):
    if not clip_name.endswith(".mp4"):
        continue

    clip_base = os.path.splitext(clip_name)[0]
    clip_path = os.path.join(partido_input_path, clip_name)

    # Cargar homografía asociada
    matrix_path = os.path.join(partido_output_path, 'homography_matrices', f"{clip_base}.npy")
    if not os.path.exists(matrix_path):
        print(f"⚠️ No se encontró homografía para {clip_name}, se omite.")
        continue

    homography_matrix = np.load(matrix_path)
    tform = transform.ProjectiveTransform()
    tform.params = homography_matrix

    # Configurar video
    cap = cv2.VideoCapture(clip_path)
    fourcc = cv2.VideoWriter_fourcc(*"avc1")
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    output_video_path = os.path.join(partido_output_path, "clips", f"{clip_base}_detected.mp4")
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # CSV de eventos
    csv_lines = []
    rim_logged = False
    frame_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame_idx += 1

        # Detección de tiros
        shoot_results = shoot_detector(frame)
        for result in shoot_results[0].boxes.data.tolist():
            x1, y1, x2, y2, conf, cls = result
            cls = int(cls)

            if shoot_detector.names[cls] == 'shoot' and conf > 0.3:

                drawBBox(frame, x1, y1, x2, y2, f"shoot {conf:.2f}", 'shoot')

                position = (int((x1 + x2) / 2), int(y2))
                drawPosition(frame, position, f"x:{position[0]} y:{position[1]}")

                # Proyectar punto a la vista del diagrama
                transformed_position = transform_point(position, tform)

                # Guardar ocurrencia de tiro con el fotograma actual y la posición proyectada
                csv_lines.append(f"s,{frame_idx},{int(transformed_position[0])},{int(transformed_position[1])}")

        # Detección de objetos
        object_results = object_detector(frame)
        for result in object_results[0].boxes.data.tolist():
            x1, y1, x2, y2, conf, cls = result
            cls = int(cls)
            label_name = object_detector.names[cls]

            if (label_name in ['player', 'rim'] and conf > 0.7) or \
                (label_name == 'basketball' and conf > 0.5):

                drawBBox(frame, x1, y1, x2, y2, f"{label_name} {conf:.2f}", label_name)

                # Anotar la posición original del aro en el primer fotograma
                if label_name == 'rim' and not rim_logged:
                    x_rim = int((x1 + x2) / 2)
                    y_rim = int((y1 + y2) / 2)
                    csv_lines.insert(0, f"r,0,{x_rim},{y_rim}")
                    rim_logged = True

            elif label_name == 'made-shot' and conf > 0.3:
                position = (int((x1 + x2) / 2), int((y1 + y2) / 2))
                drawBBox(frame, x1, y1, x2, y2, f"{label_name} {conf:.2f}", label_name)

                # Guardar ocurrencia de tiro encestado con el fotograma actual y la posición original
                csv_lines.append(f"m,{frame_idx},{position[0]},{position[1]}")

        # Guardar frame procesado
        out.write(frame)

    # Guardar CSV
    csv_path = os.path.join(partido_output_path, "csv", f"{clip_base}_events.csv")
    with open(csv_path, "w") as f:
        for line in csv_lines:
            f.write(line + "\n")

    # Liberar recursos
    cap.release()
    out.release()
    print(f"✅ Clip procesado y guardado: {output_video_path}")
    print(f"📝 CSV generado: {csv_path}")
# Out:
# 0: 576x1024 (no detections), 180.8ms
# Speed: 18.8ms preprocess, 180.8ms inference, 82.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 133.6ms
# Speed: 10.1ms preprocess, 133.6ms inference, 228.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.5ms
# Speed: 13.1ms preprocess, 114.5ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 35.9ms
# Speed: 10.3ms preprocess, 35.9ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.2ms
# Speed: 13.5ms preprocess, 114.2ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 36.5ms
# Speed: 12.6ms preprocess, 36.5ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.6ms
# Speed: 10.5ms preprocess, 115.6ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 35.7ms
# Speed: 10.7ms preprocess, 35.7ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 13.8ms preprocess, 114.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 40.9ms
# Speed: 10.2ms preprocess, 40.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 14.2ms preprocess, 113.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 34.0ms
# Speed: 10.6ms preprocess, 34.0ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.8ms
# Speed: 12.3ms preprocess, 114.8ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 34.3ms
# Speed: 10.6ms preprocess, 34.3ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.7ms preprocess, 113.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 37.8ms
# Speed: 10.8ms preprocess, 37.8ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.2ms
# Speed: 13.9ms preprocess, 115.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 36.5ms
# Speed: 10.0ms preprocess, 36.5ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.5ms preprocess, 113.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 32.5ms
# Speed: 9.2ms preprocess, 32.5ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 10.2ms preprocess, 114.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 35.4ms
# Speed: 10.5ms preprocess, 35.4ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.6ms
# Speed: 12.2ms preprocess, 116.6ms inference, 2.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 33.5ms
# Speed: 10.4ms preprocess, 33.5ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 10.9ms preprocess, 113.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 40.0ms
# Speed: 9.9ms preprocess, 40.0ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.0ms
# Speed: 10.8ms preprocess, 116.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 37.9ms
# Speed: 10.2ms preprocess, 37.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 13.7ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 32.3ms
# Speed: 10.6ms preprocess, 32.3ms inference, 3.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 11.2ms preprocess, 113.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 37.0ms
# Speed: 10.7ms preprocess, 37.0ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.9ms
# Speed: 10.6ms preprocess, 115.9ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 36.5ms
# Speed: 10.1ms preprocess, 36.5ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 11.2ms preprocess, 113.8ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 33.7ms
# Speed: 10.2ms preprocess, 33.7ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.7ms
# Speed: 11.0ms preprocess, 113.7ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 33.6ms
# Speed: 11.8ms preprocess, 33.6ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 10.6ms preprocess, 113.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 43.2ms
# Speed: 10.2ms preprocess, 43.2ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 11.2ms preprocess, 113.9ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 35.0ms
# Speed: 10.8ms preprocess, 35.0ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 11.1ms preprocess, 113.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 34.5ms
# Speed: 10.7ms preprocess, 34.5ms inference, 5.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 10.3ms preprocess, 113.6ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 71.6ms
# Speed: 10.5ms preprocess, 71.6ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.5ms
# Speed: 10.1ms preprocess, 116.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 35.0ms
# Speed: 9.6ms preprocess, 35.0ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.4ms
# Speed: 11.4ms preprocess, 113.4ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 42.4ms
# Speed: 13.2ms preprocess, 42.4ms inference, 5.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 12.1ms preprocess, 114.1ms inference, 3.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 59.3ms
# Speed: 15.3ms preprocess, 59.3ms inference, 5.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.7ms
# Speed: 12.7ms preprocess, 113.7ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 44.1ms
# Speed: 12.9ms preprocess, 44.1ms inference, 6.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.3ms
# Speed: 10.6ms preprocess, 114.3ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 48.2ms
# Speed: 9.9ms preprocess, 48.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.6ms
# Speed: 13.2ms preprocess, 116.6ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 47.7ms
# Speed: 10.1ms preprocess, 47.7ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 12.5ms preprocess, 113.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 33.5ms
# Speed: 10.1ms preprocess, 33.5ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.2ms preprocess, 113.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 43.1ms
# Speed: 13.8ms preprocess, 43.1ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 11.8ms preprocess, 114.0ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 34.6ms
# Speed: 9.4ms preprocess, 34.6ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 127.8ms
# Speed: 10.9ms preprocess, 127.8ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 38.4ms
# Speed: 10.6ms preprocess, 38.4ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 128.7ms
# Speed: 10.5ms preprocess, 128.7ms inference, 2.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 43.0ms
# Speed: 12.2ms preprocess, 43.0ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.5ms
# Speed: 10.6ms preprocess, 121.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 48.0ms
# Speed: 10.1ms preprocess, 48.0ms inference, 6.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 117.0ms
# Speed: 10.7ms preprocess, 117.0ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 40.4ms
# Speed: 9.2ms preprocess, 40.4ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.7ms
# Speed: 12.0ms preprocess, 115.7ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 34.5ms
# Speed: 10.3ms preprocess, 34.5ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 12.3ms preprocess, 113.8ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 31.5ms
# Speed: 10.1ms preprocess, 31.5ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.2ms
# Speed: 12.4ms preprocess, 114.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 33.7ms
# Speed: 9.3ms preprocess, 33.7ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 10.5ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 33.0ms
# Speed: 10.1ms preprocess, 33.0ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 12.3ms preprocess, 113.8ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 33.6ms
# Speed: 12.4ms preprocess, 33.6ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 10.6ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 8 players, 1 rim, 53.5ms
# Speed: 10.3ms preprocess, 53.5ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.4ms preprocess, 113.8ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 38.8ms
# Speed: 9.5ms preprocess, 38.8ms inference, 5.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 117.6ms
# Speed: 13.4ms preprocess, 117.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 44.7ms
# Speed: 9.9ms preprocess, 44.7ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 10.3ms preprocess, 113.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 32.7ms
# Speed: 9.9ms preprocess, 32.7ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 9.5ms preprocess, 113.9ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 41.9ms
# Speed: 9.3ms preprocess, 41.9ms inference, 6.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.9ms
# Speed: 13.6ms preprocess, 114.9ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 46.4ms
# Speed: 9.8ms preprocess, 46.4ms inference, 8.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 10.8ms preprocess, 113.9ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 34.9ms
# Speed: 9.6ms preprocess, 34.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.2ms
# Speed: 10.7ms preprocess, 116.2ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 33.0ms
# Speed: 9.6ms preprocess, 33.0ms inference, 5.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 12.3ms preprocess, 113.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 32.0ms
# Speed: 10.2ms preprocess, 32.0ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 11.3ms preprocess, 114.0ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 51.1ms
# Speed: 10.1ms preprocess, 51.1ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 10.5ms preprocess, 114.0ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 33.6ms
# Speed: 9.3ms preprocess, 33.6ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 10.7ms preprocess, 113.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 31.7ms
# Speed: 9.3ms preprocess, 31.7ms inference, 8.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.4ms
# Speed: 13.7ms preprocess, 115.4ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 33.7ms
# Speed: 9.6ms preprocess, 33.7ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 10.8ms preprocess, 113.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 30.9ms
# Speed: 10.2ms preprocess, 30.9ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 11.3ms preprocess, 113.6ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 32.8ms
# Speed: 10.0ms preprocess, 32.8ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.5ms
# Speed: 12.3ms preprocess, 114.5ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 32.4ms
# Speed: 9.8ms preprocess, 32.4ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 11.4ms preprocess, 114.0ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 32.2ms
# Speed: 9.0ms preprocess, 32.2ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.7ms preprocess, 113.8ms inference, 2.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 38.9ms
# Speed: 10.0ms preprocess, 38.9ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.7ms
# Speed: 10.0ms preprocess, 113.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 35.1ms
# Speed: 11.1ms preprocess, 35.1ms inference, 6.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.5ms
# Speed: 12.8ms preprocess, 114.5ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 31.6ms
# Speed: 9.1ms preprocess, 31.6ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.7ms
# Speed: 12.1ms preprocess, 115.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 44.1ms
# Speed: 9.8ms preprocess, 44.1ms inference, 9.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 10.2ms preprocess, 113.6ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 40.0ms
# Speed: 9.1ms preprocess, 40.0ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.4ms
# Speed: 12.7ms preprocess, 113.4ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 32.5ms
# Speed: 11.7ms preprocess, 32.5ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 shoot, 113.6ms
# Speed: 11.3ms preprocess, 113.6ms inference, 43.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 37.4ms
# Speed: 9.5ms preprocess, 37.4ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 shoot, 113.6ms
# Speed: 11.2ms preprocess, 113.6ms inference, 7.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 42.7ms
# Speed: 10.1ms preprocess, 42.7ms inference, 7.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 shoot, 116.3ms
# Speed: 11.2ms preprocess, 116.3ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 32.3ms
# Speed: 10.2ms preprocess, 32.3ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 11.3ms preprocess, 113.8ms inference, 3.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 47.8ms
# Speed: 11.0ms preprocess, 47.8ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.8ms
# Speed: 10.5ms preprocess, 114.8ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 33.6ms
# Speed: 9.6ms preprocess, 33.6ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 9.9ms preprocess, 114.0ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 54.5ms
# Speed: 14.4ms preprocess, 54.5ms inference, 5.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 143.2ms
# Speed: 13.0ms preprocess, 143.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 13 players, 1 rim, 31.8ms
# Speed: 11.1ms preprocess, 31.8ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 10.5ms preprocess, 114.0ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 34.2ms
# Speed: 9.9ms preprocess, 34.2ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.4ms
# Speed: 10.7ms preprocess, 113.4ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 41.9ms
# Speed: 10.3ms preprocess, 41.9ms inference, 5.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.3ms
# Speed: 12.7ms preprocess, 116.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 31.9ms
# Speed: 9.5ms preprocess, 31.9ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 11.5ms preprocess, 114.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 33.3ms
# Speed: 10.3ms preprocess, 33.3ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 12.2ms preprocess, 113.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 32.4ms
# Speed: 9.9ms preprocess, 32.4ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.6ms
# Speed: 9.4ms preprocess, 115.6ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 37.8ms
# Speed: 10.8ms preprocess, 37.8ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.9ms preprocess, 113.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 33.6ms
# Speed: 11.4ms preprocess, 33.6ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.1ms
# Speed: 12.3ms preprocess, 113.1ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 40.9ms
# Speed: 12.1ms preprocess, 40.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 10.5ms preprocess, 114.1ms inference, 2.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 37.1ms
# Speed: 9.4ms preprocess, 37.1ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 13.3ms preprocess, 114.1ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 30.4ms
# Speed: 9.7ms preprocess, 30.4ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.0ms
# Speed: 12.4ms preprocess, 116.0ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 7 players, 1 rim, 32.6ms
# Speed: 11.8ms preprocess, 32.6ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 11.0ms preprocess, 113.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 41.3ms
# Speed: 12.5ms preprocess, 41.3ms inference, 5.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.3ms
# Speed: 10.0ms preprocess, 113.3ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 33.2ms
# Speed: 9.6ms preprocess, 33.2ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.8ms
# Speed: 10.2ms preprocess, 114.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 33.2ms
# Speed: 9.6ms preprocess, 33.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.9ms
# Speed: 10.6ms preprocess, 113.9ms inference, 3.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 53.5ms
# Speed: 9.9ms preprocess, 53.5ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.8ms
# Speed: 10.4ms preprocess, 114.8ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 36.4ms
# Speed: 9.8ms preprocess, 36.4ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 11.2ms preprocess, 113.6ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 36.4ms
# Speed: 10.3ms preprocess, 36.4ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.2ms
# Speed: 12.7ms preprocess, 114.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 33.4ms
# Speed: 9.6ms preprocess, 33.4ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.4ms
# Speed: 11.5ms preprocess, 113.4ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 34.2ms
# Speed: 11.0ms preprocess, 34.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.0ms preprocess, 113.8ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 40.0ms
# Speed: 10.3ms preprocess, 40.0ms inference, 6.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 116.4ms
# Speed: 12.1ms preprocess, 116.4ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 35.8ms
# Speed: 11.2ms preprocess, 35.8ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.8ms
# Speed: 10.3ms preprocess, 113.8ms inference, 3.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 43.6ms
# Speed: 10.8ms preprocess, 43.6ms inference, 5.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.2ms
# Speed: 13.7ms preprocess, 115.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 36.3ms
# Speed: 10.1ms preprocess, 36.3ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 151.1ms
# Speed: 13.0ms preprocess, 151.1ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 35.3ms
# Speed: 10.1ms preprocess, 35.3ms inference, 4.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.2ms
# Speed: 13.0ms preprocess, 123.2ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 44.0ms
# Speed: 9.9ms preprocess, 44.0ms inference, 6.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 124.4ms
# Speed: 9.9ms preprocess, 124.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 58.5ms
# Speed: 10.7ms preprocess, 58.5ms inference, 7.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 10.1ms preprocess, 113.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 45.4ms
# Speed: 9.5ms preprocess, 45.4ms inference, 6.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.7ms
# Speed: 11.0ms preprocess, 113.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 41.1ms
# Speed: 8.8ms preprocess, 41.1ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.4ms
# Speed: 13.8ms preprocess, 113.4ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 47.3ms
# Speed: 12.1ms preprocess, 47.3ms inference, 6.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.2ms
# Speed: 12.9ms preprocess, 114.2ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 42.1ms
# Speed: 10.7ms preprocess, 42.1ms inference, 5.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 134.5ms
# Speed: 10.1ms preprocess, 134.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 40.3ms
# Speed: 9.9ms preprocess, 40.3ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 133.5ms
# Speed: 10.5ms preprocess, 133.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 37.1ms
# Speed: 10.0ms preprocess, 37.1ms inference, 6.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 134.2ms
# Speed: 13.5ms preprocess, 134.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 35.6ms
# Speed: 9.3ms preprocess, 35.6ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.0ms
# Speed: 10.3ms preprocess, 114.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 33.5ms
# Speed: 11.8ms preprocess, 33.5ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.4ms
# Speed: 11.0ms preprocess, 114.4ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 56.6ms
# Speed: 10.4ms preprocess, 56.6ms inference, 4.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 117.8ms
# Speed: 10.9ms preprocess, 117.8ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 30.5ms
# Speed: 9.6ms preprocess, 30.5ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 129.2ms
# Speed: 11.6ms preprocess, 129.2ms inference, 2.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 33.2ms
# Speed: 9.8ms preprocess, 33.2ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.9ms
# Speed: 11.2ms preprocess, 114.9ms inference, 3.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 67.1ms
# Speed: 12.0ms preprocess, 67.1ms inference, 6.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 133.6ms
# Speed: 11.1ms preprocess, 133.6ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 40.7ms
# Speed: 10.8ms preprocess, 40.7ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 133.5ms
# Speed: 11.9ms preprocess, 133.5ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 43.2ms
# Speed: 10.1ms preprocess, 43.2ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.6ms
# Speed: 12.3ms preprocess, 115.6ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 56.4ms
# Speed: 10.3ms preprocess, 56.4ms inference, 6.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 173.0ms
# Speed: 14.7ms preprocess, 173.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 31.7ms
# Speed: 10.1ms preprocess, 31.7ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 140.1ms
# Speed: 12.7ms preprocess, 140.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 33.2ms
# Speed: 12.1ms preprocess, 33.2ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 127.5ms
# Speed: 9.6ms preprocess, 127.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 32.8ms
# Speed: 10.9ms preprocess, 32.8ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.3ms
# Speed: 10.7ms preprocess, 114.3ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 43.8ms
# Speed: 10.9ms preprocess, 43.8ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 130.5ms
# Speed: 15.4ms preprocess, 130.5ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 93.8ms
# Speed: 11.7ms preprocess, 93.8ms inference, 9.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 147.6ms
# Speed: 18.7ms preprocess, 147.6ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 33.1ms
# Speed: 11.8ms preprocess, 33.1ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 138.8ms
# Speed: 12.6ms preprocess, 138.8ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 60.4ms
# Speed: 12.0ms preprocess, 60.4ms inference, 7.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 135.6ms
# Speed: 12.7ms preprocess, 135.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 43.9ms
# Speed: 10.5ms preprocess, 43.9ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.1ms
# Speed: 10.7ms preprocess, 131.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 44.9ms
# Speed: 9.0ms preprocess, 44.9ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 135.1ms
# Speed: 11.3ms preprocess, 135.1ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 37.0ms
# Speed: 10.5ms preprocess, 37.0ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.2ms
# Speed: 11.6ms preprocess, 132.2ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 51.2ms
# Speed: 9.9ms preprocess, 51.2ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.2ms
# Speed: 10.9ms preprocess, 132.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 35.8ms
# Speed: 10.9ms preprocess, 35.8ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.4ms
# Speed: 10.7ms preprocess, 131.4ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 39.0ms
# Speed: 10.2ms preprocess, 39.0ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 128.7ms
# Speed: 10.2ms preprocess, 128.7ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 39.9ms
# Speed: 12.6ms preprocess, 39.9ms inference, 5.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 137.5ms
# Speed: 12.4ms preprocess, 137.5ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 33.0ms
# Speed: 9.8ms preprocess, 33.0ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 130.7ms
# Speed: 12.1ms preprocess, 130.7ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 38.7ms
# Speed: 9.3ms preprocess, 38.7ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 134.6ms
# Speed: 10.8ms preprocess, 134.6ms inference, 2.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 40.0ms
# Speed: 11.1ms preprocess, 40.0ms inference, 5.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.7ms
# Speed: 12.8ms preprocess, 132.7ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 35.6ms
# Speed: 9.6ms preprocess, 35.6ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 128.2ms
# Speed: 9.9ms preprocess, 128.2ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 40.8ms
# Speed: 10.4ms preprocess, 40.8ms inference, 5.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.1ms
# Speed: 13.9ms preprocess, 131.1ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 34.4ms
# Speed: 9.8ms preprocess, 34.4ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.8ms
# Speed: 12.8ms preprocess, 132.8ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 29.9ms
# Speed: 11.8ms preprocess, 29.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.5ms
# Speed: 10.5ms preprocess, 132.5ms inference, 3.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 41.4ms
# Speed: 10.2ms preprocess, 41.4ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 130.5ms
# Speed: 9.8ms preprocess, 130.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 40.9ms
# Speed: 10.7ms preprocess, 40.9ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.7ms
# Speed: 11.6ms preprocess, 132.7ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 37.4ms
# Speed: 11.6ms preprocess, 37.4ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.1ms
# Speed: 9.9ms preprocess, 131.1ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 35.2ms
# Speed: 9.4ms preprocess, 35.2ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 130.3ms
# Speed: 10.9ms preprocess, 130.3ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 37.2ms
# Speed: 12.6ms preprocess, 37.2ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 135.3ms
# Speed: 9.4ms preprocess, 135.3ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 35.2ms
# Speed: 9.6ms preprocess, 35.2ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 138.6ms
# Speed: 11.3ms preprocess, 138.6ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 35.6ms
# Speed: 9.1ms preprocess, 35.6ms inference, 3.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 133.6ms
# Speed: 10.3ms preprocess, 133.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 33.3ms
# Speed: 8.9ms preprocess, 33.3ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 133.5ms
# Speed: 12.0ms preprocess, 133.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 33.2ms
# Speed: 9.2ms preprocess, 33.2ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 164.9ms
# Speed: 10.8ms preprocess, 164.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 29.6ms
# Speed: 8.8ms preprocess, 29.6ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 149.6ms
# Speed: 9.8ms preprocess, 149.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 40.0ms
# Speed: 10.9ms preprocess, 40.0ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 166.0ms
# Speed: 15.0ms preprocess, 166.0ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 1 rim, 35.4ms
# Speed: 11.7ms preprocess, 35.4ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 133.2ms
# Speed: 11.3ms preprocess, 133.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 47.1ms
# Speed: 10.3ms preprocess, 47.1ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 150.0ms
# Speed: 10.4ms preprocess, 150.0ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 35.4ms
# Speed: 10.6ms preprocess, 35.4ms inference, 5.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 150.6ms
# Speed: 12.2ms preprocess, 150.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 36.9ms
# Speed: 9.5ms preprocess, 36.9ms inference, 5.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 150.7ms
# Speed: 12.3ms preprocess, 150.7ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 35.4ms
# Speed: 9.4ms preprocess, 35.4ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.1ms
# Speed: 9.8ms preprocess, 131.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 32.6ms
# Speed: 9.4ms preprocess, 32.6ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 120.5ms
# Speed: 9.5ms preprocess, 120.5ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 37.9ms
# Speed: 13.9ms preprocess, 37.9ms inference, 8.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 140.6ms
# Speed: 9.7ms preprocess, 140.6ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 33.0ms
# Speed: 11.1ms preprocess, 33.0ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 129.9ms
# Speed: 9.9ms preprocess, 129.9ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 47.2ms
# Speed: 12.8ms preprocess, 47.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.7ms
# Speed: 9.9ms preprocess, 113.7ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 36.3ms
# Speed: 10.2ms preprocess, 36.3ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 113.6ms
# Speed: 12.5ms preprocess, 113.6ms inference, 3.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 32.8ms
# Speed: 10.0ms preprocess, 32.8ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 114.1ms
# Speed: 9.9ms preprocess, 114.1ms inference, 2.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 29.0ms
# Speed: 10.6ms preprocess, 29.0ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 135.8ms
# Speed: 9.1ms preprocess, 135.8ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 40.7ms
# Speed: 12.8ms preprocess, 40.7ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 125.3ms
# Speed: 10.1ms preprocess, 125.3ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 31.2ms
# Speed: 11.0ms preprocess, 31.2ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.3ms
# Speed: 11.6ms preprocess, 123.3ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 33.1ms
# Speed: 10.0ms preprocess, 33.1ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 129.1ms
# Speed: 9.2ms preprocess, 129.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 30.2ms
# Speed: 9.8ms preprocess, 30.2ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 119.5ms
# Speed: 10.8ms preprocess, 119.5ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 29.3ms
# Speed: 10.4ms preprocess, 29.3ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.7ms
# Speed: 9.6ms preprocess, 123.7ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 30.9ms
# Speed: 9.0ms preprocess, 30.9ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 143.9ms
# Speed: 14.7ms preprocess, 143.9ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 23.3ms
# Speed: 7.0ms preprocess, 23.3ms inference, 2.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 146.9ms
# Speed: 10.1ms preprocess, 146.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 25.8ms
# Speed: 7.3ms preprocess, 25.8ms inference, 6.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 120.8ms
# Speed: 7.5ms preprocess, 120.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 1 rim, 29.9ms
# Speed: 8.2ms preprocess, 29.9ms inference, 5.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 132.2ms
# Speed: 8.1ms preprocess, 132.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 36.5ms
# Speed: 10.9ms preprocess, 36.5ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.5ms
# Speed: 12.9ms preprocess, 121.5ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 33.0ms
# Speed: 12.5ms preprocess, 33.0ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 117.6ms
# Speed: 11.8ms preprocess, 117.6ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 38.2ms
# Speed: 11.0ms preprocess, 38.2ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.2ms
# Speed: 14.8ms preprocess, 115.2ms inference, 2.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 12 players, 1 rim, 40.4ms
# Speed: 10.6ms preprocess, 40.4ms inference, 5.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 115.2ms
# ...
#
# 0: 576x1024 (no detections), 121.2ms
# Speed: 11.5ms preprocess, 121.2ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 34.1ms
# Speed: 11.4ms preprocess, 34.1ms inference, 4.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 124.2ms
# Speed: 11.1ms preprocess, 124.2ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 60.8ms
# Speed: 10.4ms preprocess, 60.8ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 125.5ms
# Speed: 12.7ms preprocess, 125.5ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 37.8ms
# Speed: 10.1ms preprocess, 37.8ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 159.5ms
# Speed: 12.5ms preprocess, 159.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 34.5ms
# Speed: 10.8ms preprocess, 34.5ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.1ms
# Speed: 12.6ms preprocess, 122.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 33.6ms
# Speed: 10.5ms preprocess, 33.6ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.6ms
# Speed: 11.6ms preprocess, 121.6ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 65.0ms
# Speed: 10.5ms preprocess, 65.0ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 166.3ms
# Speed: 13.5ms preprocess, 166.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 1 rim, 38.2ms
# Speed: 9.2ms preprocess, 38.2ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.3ms
# Speed: 11.6ms preprocess, 122.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 35.1ms
# Speed: 9.7ms preprocess, 35.1ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.1ms
# Speed: 10.8ms preprocess, 121.1ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 50.1ms
# Speed: 10.6ms preprocess, 50.1ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 124.8ms
# Speed: 11.8ms preprocess, 124.8ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 35.2ms
# Speed: 10.9ms preprocess, 35.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.3ms
# Speed: 11.7ms preprocess, 123.3ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 11 players, 1 rim, 43.2ms
# Speed: 10.4ms preprocess, 43.2ms inference, 5.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 125.2ms
# Speed: 10.9ms preprocess, 125.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 45.9ms
# Speed: 11.6ms preprocess, 45.9ms inference, 3.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 126.9ms
# Speed: 18.8ms preprocess, 126.9ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 1 rim, 40.2ms
# Speed: 9.8ms preprocess, 40.2ms inference, 7.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 178.5ms
# Speed: 10.3ms preprocess, 178.5ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 32.4ms
# Speed: 13.9ms preprocess, 32.4ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 120.4ms
# Speed: 10.6ms preprocess, 120.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 8 players, 1 rim, 33.0ms
# Speed: 10.6ms preprocess, 33.0ms inference, 4.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.1ms
# Speed: 10.8ms preprocess, 122.1ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 36.8ms
# Speed: 10.6ms preprocess, 36.8ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 148.8ms
# Speed: 16.6ms preprocess, 148.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 9 players, 1 rim, 76.0ms
# Speed: 11.1ms preprocess, 76.0ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.7ms
# Speed: 12.4ms preprocess, 121.7ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 10 players, 1 rim, 35.7ms
# Speed: 12.2ms preprocess, 35.7ms inference, 5.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.7ms
# Speed: 12.5ms preprocess, 123.7ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 4 basketballs, 10 players, 1 rim, 35.9ms
# Speed: 10.4ms preprocess, 35.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.1ms
# Speed: 12.5ms preprocess, 123.1ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 37.1ms
# Speed: 11.3ms preprocess, 37.1ms inference, 3.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.3ms
# Speed: 12.8ms preprocess, 122.3ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 4 basketballs, 12 players, 1 rim, 37.0ms
# Speed: 10.5ms preprocess, 37.0ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 169.1ms
# Speed: 12.3ms preprocess, 169.1ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 10 players, 1 rim, 47.2ms
# Speed: 10.8ms preprocess, 47.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.6ms
# Speed: 12.6ms preprocess, 121.6ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 10 players, 1 rim, 54.9ms
# Speed: 11.1ms preprocess, 54.9ms inference, 11.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.2ms
# Speed: 12.8ms preprocess, 123.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 10 players, 1 rim, 36.2ms
# Speed: 10.0ms preprocess, 36.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 128.5ms
# Speed: 14.0ms preprocess, 128.5ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 8 players, 1 rim, 49.3ms
# Speed: 10.2ms preprocess, 49.3ms inference, 6.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 170.2ms
# Speed: 12.0ms preprocess, 170.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 9 players, 37.5ms
# Speed: 10.4ms preprocess, 37.5ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 126.6ms
# Speed: 11.9ms preprocess, 126.6ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 11 players, 35.2ms
# Speed: 11.0ms preprocess, 35.2ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.5ms
# Speed: 10.4ms preprocess, 131.5ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 35.4ms
# Speed: 10.1ms preprocess, 35.4ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.9ms
# Speed: 12.7ms preprocess, 122.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 34.9ms
# Speed: 9.9ms preprocess, 34.9ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.1ms
# Speed: 10.3ms preprocess, 123.1ms inference, 2.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 37.6ms
# Speed: 9.9ms preprocess, 37.6ms inference, 6.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.8ms
# Speed: 12.6ms preprocess, 123.8ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 11 players, 33.3ms
# Speed: 9.0ms preprocess, 33.3ms inference, 3.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 159.8ms
# Speed: 11.4ms preprocess, 159.8ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 8 players, 35.1ms
# Speed: 11.2ms preprocess, 35.1ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.2ms
# Speed: 11.5ms preprocess, 131.2ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 37.5ms
# Speed: 10.3ms preprocess, 37.5ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 142.2ms
# Speed: 13.2ms preprocess, 142.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 10 players, 38.6ms
# Speed: 9.4ms preprocess, 38.6ms inference, 4.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 124.2ms
# Speed: 13.2ms preprocess, 124.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 35.9ms
# Speed: 10.5ms preprocess, 35.9ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 120.9ms
# Speed: 10.7ms preprocess, 120.9ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 40.8ms
# Speed: 11.6ms preprocess, 40.8ms inference, 5.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 124.0ms
# Speed: 11.7ms preprocess, 124.0ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 37.4ms
# Speed: 15.3ms preprocess, 37.4ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 131.9ms
# Speed: 12.3ms preprocess, 131.9ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 35.6ms
# Speed: 10.2ms preprocess, 35.6ms inference, 4.4ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 120.7ms
# Speed: 12.4ms preprocess, 120.7ms inference, 2.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 60.6ms
# Speed: 10.9ms preprocess, 60.6ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.7ms
# Speed: 12.6ms preprocess, 122.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 36.4ms
# Speed: 11.3ms preprocess, 36.4ms inference, 4.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 202.5ms
# Speed: 12.1ms preprocess, 202.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 10 players, 1 rim, 34.9ms
# Speed: 10.9ms preprocess, 34.9ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 123.7ms
# Speed: 11.6ms preprocess, 123.7ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 33.3ms
# Speed: 10.4ms preprocess, 33.3ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 122.9ms
# Speed: 12.4ms preprocess, 122.9ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 46.5ms
# Speed: 11.1ms preprocess, 46.5ms inference, 4.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 119.7ms
# Speed: 12.8ms preprocess, 119.7ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 37.0ms
# Speed: 11.1ms preprocess, 37.0ms inference, 4.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.5ms
# Speed: 10.4ms preprocess, 121.5ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 35.4ms
# Speed: 9.8ms preprocess, 35.4ms inference, 4.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.7ms
# Speed: 12.1ms preprocess, 121.7ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 9 players, 1 rim, 37.6ms
# Speed: 10.6ms preprocess, 37.6ms inference, 5.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 186.2ms
# Speed: 11.5ms preprocess, 186.2ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 1 rim, 42.6ms
# Speed: 9.8ms preprocess, 42.6ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.2ms
# Speed: 11.1ms preprocess, 121.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 10 players, 1 rim, 80.5ms
# Speed: 10.3ms preprocess, 80.5ms inference, 3.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.9ms
# Speed: 10.1ms preprocess, 121.9ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 9 players, 1 rim, 35.5ms
# Speed: 10.6ms preprocess, 35.5ms inference, 5.5ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 119.8ms
# Speed: 11.4ms preprocess, 119.8ms inference, 2.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 4 basketballs, 9 players, 44.8ms
# Speed: 10.6ms preprocess, 44.8ms inference, 5.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.8ms
# Speed: 12.3ms preprocess, 121.8ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 37.0ms
# Speed: 9.8ms preprocess, 37.0ms inference, 5.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.8ms
# Speed: 11.6ms preprocess, 121.8ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 67.7ms
# Speed: 10.5ms preprocess, 67.7ms inference, 5.2ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 121.3ms
# Speed: 10.3ms preprocess, 121.3ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 2 basketballs, 9 players, 35.3ms
# Speed: 10.9ms preprocess, 35.3ms inference, 4.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 146.3ms
# Speed: 12.5ms preprocess, 146.3ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 3 basketballs, 9 players, 33.4ms
# Speed: 11.2ms preprocess, 33.4ms inference, 5.1ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 (no detections), 138.2ms
# Speed: 11.3ms preprocess, 138.2ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 1024)
#
# 0: 576x1024 1 basketball, 7 players, 1 rim, 32.6ms
# Speed: 10.3ms preprocess, 32.6ms inference, 3.9ms postprocess per image at shape (1, 3, 576, 1024)
# ✅ Clip procesado y guardado: output\partido1\clips\ClipS2_detected.mp4
# 📝 CSV generado: output\partido1\csv\ClipS2_events.csv

# %% [markdown]
# Shoot Analysis

# %%
import os
import pickle
from glob import glob
import numpy as np
import pandas as pd
from shapely.geometry import Point, Polygon, MultiPolygon
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from collections import defaultdict
import re


img_path = "assets/court_diagrams/fiba_white_court_half.png"
court_img = cv2.imread(img_path)
court_img = cv2.cvtColor(court_img, cv2.COLOR_BGR2RGB)

# -------------------------------
# CARGAR ZONAS DESDE PICKLE
# -------------------------------
with open("modules/data_analysis/court_zones.pkl", "rb") as f:
    zonas_estudio = pickle.load(f)

print("✅ Zonas cargadas desde archivo pickle:")
for nombre in zonas_estudio:
    print("  -", nombre)

# -------------------------------
# RECORRER TODOS LOS PARTIDOS EN OUTPUT_DIR
# -------------------------------

zonas_detectadas_global = []

def asignar_zona(point, zonas_dict):
    for nombre, poly in zonas_dict.items():
        if poly.contains(point):
            return nombre
    return None


csv_folder = os.path.join(partido_output_path, "csv")

print(f"\n📂 Procesando CSVs del partido: {partido}")
csv_files = sorted(glob(os.path.join(csv_folder, "*.csv")))

for csv_path in csv_files:
    df = pd.read_csv(csv_path, header=None, names=['tipo', 'frame', 'x', 'y'])

    rim_row = df[df['tipo'] == 'r']
    if rim_row.empty:
        continue
    rim_pos = (rim_row.iloc[0]['x'], rim_row.iloc[0]['y'])

    shots = df[df['tipo'] == 's'][['frame', 'x', 'y']]
    mades = df[df['tipo'] == 'm'][['frame', 'x', 'y']]

    clusters = []
    current_cluster = []
    last_frame = -10

    for _, row in shots.iterrows():
        if row['frame'] - last_frame > 3 and current_cluster:
            clusters.append(current_cluster)
            current_cluster = []
        current_cluster.append((int(row['frame']), row['x'], row['y']))
        last_frame = row['frame']

    if current_cluster:
        clusters.append(current_cluster)

    main_cluster = max(clusters, key=lambda c: len(c)) if clusters else []
    cleaned_shots = []

    if main_cluster:
        cluster = np.array(main_cluster)
        avg_frame = int(np.mean(cluster[:, 0]))
        avg_x = np.mean(cluster[:, 1])
        avg_y = np.mean(cluster[:, 2])
        cleaned_shots.append(('s', avg_frame, avg_x, avg_y))

    if not mades.empty:
        made_array = mades[['frame', 'x', 'y']].values
        center_idx = len(made_array) // 2
        cleaned_shots.append(('m', int(made_array[center_idx][0]),
                                made_array[center_idx][1],
                                made_array[center_idx][2]))

    has_made = any(tipo == 'm' for tipo, *_ in cleaned_shots)
    for tipo, frame, x, y in cleaned_shots:
        if tipo == 's':
            punto = Point(x, y)
            zona = asignar_zona(punto, zonas_estudio)
            if zona:
                zonas_detectadas_global.append((zona, has_made, x, y))

# -------------------------------
# PREPARAR DIRECTORIO DE ANÁLISIS
# -------------------------------

# Asegurarse de que haya al menos un partido válido para usar su ruta
if 'partido_output_path' in locals():
    analysis_path = os.path.join(partido_output_path, "analysis")
    os.makedirs(analysis_path, exist_ok=True)

    stats_csv_path = os.path.join(analysis_path, "shot_stats.csv")
    heatmap_img_path = os.path.join(analysis_path, "shot_heatmap.png")
    shot_chart_img_path = os.path.join(analysis_path, "shot_chart.png")


# -------------------------------
# TABLA DE EFECTIVIDAD
# -------------------------------

def numero_zona(zona):
    match = re.search(r'Zona (\d+)', zona)
    return int(match.group(1)) if match else float('inf')

conteo = defaultdict(lambda: {'aciertos': 0, 'intentos': 0})

for zona, acierto, _, _ in zonas_detectadas_global:
    conteo[zona]['intentos'] += 1
    if acierto:
        conteo[zona]['aciertos'] += 1

df_stats = pd.DataFrame([
    {
        'Zona': zona,
        'Aciertos': datos['aciertos'],
        'Intentos': datos['intentos'],
        'Efectividad (%)': 100 * datos['aciertos'] / datos['intentos'] if datos['intentos'] > 0 else 0
    }
    for zona, datos in conteo.items()
])

for nombre in zonas_estudio.keys():
    if nombre not in df_stats['Zona'].values:
        df_stats = pd.concat([df_stats, pd.DataFrame([{
            'Zona': nombre,
            'Aciertos': 0,
            'Intentos': 0,
            'Efectividad (%)': 0.0
        }])], ignore_index=True)

df_stats = df_stats.sort_values(by='Zona', key=lambda x: x.map(numero_zona)).reset_index(drop=True)

# Mostrar tabla
display(df_stats)
df_stats.to_csv(stats_csv_path, index=False)
print(f"📄 Archivo CSV guardado en: {stats_csv_path}")

# -------------------------------
# DIAGRAMA DE TIROS INDIVIDUALES
# -------------------------------
plt.figure(figsize=(10, 6))
ax = plt.gca()
ax.imshow(court_img)

for nombre, zona in zonas_estudio.items():
    if isinstance(zona, Polygon):
        coords = np.array(zona.exterior.coords)
        patch = patches.Polygon(coords, facecolor='none', edgecolor='black', alpha=0.3)
        ax.add_patch(patch)
    elif isinstance(zona, MultiPolygon):
        largest_poly = max(zona.geoms, key=lambda g: g.area)
        coords = np.array(largest_poly.exterior.coords)
        patch = patches.Polygon(coords, facecolor='none', edgecolor='black', alpha=0.3)
        ax.add_patch(patch)

for _, acierto, x, y in zonas_detectadas_global:
    if acierto:
        ax.plot(x, y, 'o', color='green', markersize=6)
    else:
        ax.text(x, y, 'X', color='red', fontsize=10,
                ha='center', va='center', weight='bold')

plt.title("Mapa de tiros individuales (aciertos y fallos)", fontsize=14)
plt.axis('off')
plt.tight_layout()

plt.savefig(shot_chart_img_path, dpi=300)
print(f"🖼️ Mapa de tiros individuales guardado en: {shot_chart_img_path}")

# -------------------------------
# HEATMAP DE EFECTIVIDAD
# -------------------------------

plt.figure(figsize=(10, 6))
ax = plt.gca()
ax.imshow(court_img)

max_efectividad = df_stats['Efectividad (%)'].max()

for nombre, zona in zonas_estudio.items():
    efectividad = df_stats.loc[df_stats['Zona'] == nombre, 'Efectividad (%)'].values[0]
    intentos = df_stats.loc[df_stats['Zona'] == nombre, 'Intentos'].values[0]
    aciertos = df_stats.loc[df_stats['Zona'] == nombre, 'Aciertos'].values[0]

    intensidad = efectividad / max_efectividad if max_efectividad > 0 else 0
    color = plt.cm.Greens(intensidad)

    if isinstance(zona, Polygon):
        coords = np.array(zona.exterior.coords)
        patch = patches.Polygon(coords, facecolor=color, edgecolor='black', alpha=0.6)
        ax.add_patch(patch)
        centroid = zona.centroid
        cx, cy = centroid.x, centroid.y
    elif isinstance(zona, MultiPolygon):
        largest_poly = max(zona.geoms, key=lambda g: g.area)
        coords = np.array(largest_poly.exterior.coords)
        patch = patches.Polygon(coords, facecolor=color, edgecolor='black', alpha=0.6)
        ax.add_patch(patch)
        centroid = largest_poly.centroid
        cx, cy = centroid.x, centroid.y

    if intentos > 0:
        # Añadir texto con porcentaje y fracción
        ax.text(cx, cy - 6, f'{efectividad:.0f}%', color='black',
                fontsize=10, ha='center', va='center', weight='bold')
        ax.text(cx, cy + 8, f'{aciertos}/{intentos}', color='black',
                fontsize=7, ha='center', va='center')
    else:
        ax.text(cx, cy, '-', color='gray', fontsize=10, ha='center', va='center', style='italic')

plt.title('Mapa de calor por efectividad (%)', fontsize=14)
plt.axis('off')
plt.tight_layout()

plt.savefig(heatmap_img_path, dpi=300)
print(f"🖼️ Heatmap guardado en: {heatmap_img_path}")
# Out:
# ✅ Zonas cargadas desde archivo pickle:
#   - Zona 1 - Triple frontal
#   - Zona 2 - Triple ala dcha
#   - Zona 3 - Triple ala izq
#   - Zona 4 - Triple esquina dcha
#   - Zona 5 - Triple esquina izq
#   - Zona 6 - Dos frontal
#   - Zona 7 - Dos ala dcha
#   - Zona 8 - Dos ala izq
#   - Zona 9 - Dos esquina dcha
#   - Zona 10 - Dos esquina izq
#   - Zona 11 - Zona 3 segs
#
# 📂 Procesando CSVs del partido: partido1
#                             Zona  Aciertos  Intentos  Efectividad (%)
# 0        Zona 1 - Triple frontal         0         1              0.0
# 1       Zona 2 - Triple ala dcha         1         1            100.0
# 2        Zona 3 - Triple ala izq         0         0              0.0
# 3   Zona 4 - Triple esquina dcha         0         0              0.0
# 4    Zona 5 - Triple esquina izq         0         0              0.0
# 5           Zona 6 - Dos frontal         0         0              0.0
# 6          Zona 7 - Dos ala dcha         0         0              0.0
# 7           Zona 8 - Dos ala izq         0         0              0.0
# 8      Zona 9 - Dos esquina dcha         0         0              0.0
# 9      Zona 10 - Dos esquina izq         0         0              0.0
# 10         Zona 11 - Zona 3 segs         1         1            100.0
# 📄 Archivo CSV guardado en: output\partido1\analysis\shot_stats.csv
# 🖼️ Mapa de tiros individuales guardado en: output\partido1\analysis\shot_chart.png
# 🖼️ Heatmap guardado en: output\partido1\analysis\shot_heatmap.png
